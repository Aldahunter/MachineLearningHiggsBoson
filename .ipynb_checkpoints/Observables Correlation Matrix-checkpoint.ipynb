# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from events import load_event_DataFrames, add_Z_bosons, add_higgs_mass

# %% [markdown]
# ## Import Data

# %%
event = "pp_h_2mu2e"

# %%
sgn_df, bkg_df = load_event_DataFrames("pp_h_2mu2e")

# %%
def add_complex_observables(df):
    df = add_Z_bosons(df)
    df = add_higgs_mass(df)
    return df

# %%
sgn_df = add_complex_observables(sgn_df)

# %%
bkg_df = add_complex_observables(bkg_df)

# %%
sgn_df.head()
# Out:
#       mu-_m      mu-_E     mu-_px     mu-_py     mu-_pz     mu-_pT   mu-_rap  \
# 0  0.000000  66.494157  39.575769  20.860329  49.194290  44.736951  0.950101
# 1  0.000230  51.185606  48.544686  -7.254285  14.517406  49.083716  0.291617
# 2  0.000000  16.991804  -3.470274 -16.607017  -0.941054  16.965725 -0.055440
# 3  0.000091  10.731395   8.253176   6.044059  -3.243035  10.229641 -0.311940
# 4  0.000000  15.248995  11.466047   9.119207   4.231039  14.650262  0.284932
#
#       mu+_m       mu+_E     mu+_px   ...        e-_py      e-_pz      e-_pT  \
# 0  0.001098  114.235663 -33.318401   ...    -1.171112  21.583793  12.897970
# 1  0.000000   45.570474 -24.720669   ...   -11.142702  -0.434664  16.737670
# 2  0.000108   11.743221   7.628213   ...   -16.306836 -54.823944  30.856349
# 3  0.000080   24.126780 -15.839974   ...    32.286957  23.882123  40.051944
# 4  0.000021   13.680731  12.110565   ...   -29.604091  53.195987  43.410834
#
#      e-_rap    Z_mu_pT  Z_mu_rap     Z_e_pT   Z_e_rap         m_H  signal
# 0  1.287268   6.991677  1.301299   6.991677  1.495242  124.993511       1
# 1 -0.025966  28.158579 -0.173541  28.158579 -0.241172  125.009913       1
# 2 -1.339092  25.664779 -0.100001  25.664779 -0.730363  124.998685       1
# 3  0.565631   7.596625 -0.664636   7.596625 -0.056160  124.999027       1
# 4  1.032138  28.045765  0.080357  28.045765  0.280515  124.981475       1
#
# [5 rows x 34 columns]

# %%
bkg_df.head()
# Out:
#    mu-_m       mu-_E      mu-_px     mu-_py      mu-_pz      mu-_pT   mu-_rap  \
# 0    0.0   60.774006  -50.052174  -1.093737  -34.453786   50.064123 -0.642967
# 1    0.0  333.297101  159.997451 -63.212087  285.468046  172.031835  1.280046
# 2    0.0  186.702722  -42.551377   7.448778  181.636457   43.198426  2.143200
# 3    0.0  122.358563 -107.727249 -30.900223  -49.108389  112.071334 -0.425255
# 4    0.0   47.821393   20.674006  35.127214   25.010996   40.759486  0.580472
#
#       mu+_m       mu+_E     mu+_px   ...        e-_py       e-_pz       e-_pT  \
# 0  0.000000   64.934756  34.790262   ...   -33.016096  -86.860053   43.450147
# 1  0.001051  288.588194  59.198839   ...    29.473437  -66.205448   89.161960
# 2  0.000154   28.795483  14.559827   ...     9.874897  -43.948468   18.473434
# 3  0.000000  110.873291 -82.646737   ...   -38.329926 -487.375821  129.651947
# 4  0.000364   85.209361 -56.546338   ...    38.115396  131.208216   38.149415
#
#      e-_rap     Z_mu_pT  Z_mu_rap      Z_e_pT   Z_e_rap         m_H  signal
# Z_e_rap  -0.006368 -0.003455  0.008915 -0.005772  0.392735 -0.000305
# m_H       0.303898  0.563171 -0.024508 -0.000546 -0.032063  0.715821
# signal   -0.057319 -0.106910  0.011322 -0.008009 -0.003214 -0.063061
#
#            mu-_rap     mu+_m     mu+_E    mu+_px    ...        e-_py  \
# mu-_m    -0.004259  0.084478  0.159575 -0.018435    ...     0.007939
# mu-_E    -0.009838  0.170324  0.306683 -0.016574    ...     0.005997
# mu-_px    0.001385 -0.018345 -0.020401  0.085199    ...     0.004014
# mu-_py   -0.002876  0.019539  0.007298 -0.003990    ...    -0.534954
# mu-_pz    0.756165 -0.013887 -0.023124  0.002336    ...     0.000840
# mu-_pT   -0.006795  0.120953  0.234050 -0.013225    ...     0.012293
# mu-_rap   1.000000  0.001012 -0.002568 -0.002978    ...     0.000780
# mu+_m     0.001012  1.000000  0.514546 -0.001896    ...    -0.009388
# mu+_E    -0.002568  0.514546  1.000000 -0.038344    ...    -0.007115
# mu+_px   -0.002978 -0.001896 -0.038344  1.000000    ...    -0.005608
# mu+_py    0.001897 -0.008842 -0.022033  0.004742    ...    -0.535539
# mu+_pz    0.500231 -0.014982 -0.015577 -0.011104    ...    -0.008770
# mu+_pT   -0.001854  0.370315  0.735199 -0.047218    ...     0.006021
# mu+_rap   0.564995  0.006213  0.002146 -0.007013    ...    -0.002887
# e+_m     -0.008328  0.092442  0.169481 -0.020301    ...    -0.003196
# e+_E     -0.000400  0.176775  0.350502 -0.024604    ...    -0.007683
# e+_px     0.003326  0.007913  0.030407 -0.538000    ...     0.002336
# e+_py     0.000225 -0.001447  0.021837  0.004943    ...     0.068643
# e+_pz     0.341310  0.007914  0.010852  0.027212    ...    -0.007426
# e+_pT    -0.000013  0.216509  0.409575 -0.016554    ...    -0.006437
# e+_rap    0.482180  0.005604  0.004516  0.007882    ...     0.000250
# e-_m     -0.000943  0.110943  0.175824 -0.002823    ...    -0.006641
# e-_E     -0.006325  0.179679  0.341250 -0.035649    ...     0.006997
# e-_px    -0.001735  0.012508  0.028785 -0.555257    ...    -0.000742
# e-_py     0.000780 -0.009388 -0.007115 -0.005608    ...     1.000000
# e-_pz     0.347635  0.002981 -0.007196  0.021781    ...     0.022540
# e-_pT    -0.006568  0.203447  0.399734 -0.040896    ...     0.032282
# e-_rap    0.486307  0.007100  0.003846  0.009309    ...     0.002412
# Z_mu_pT  -0.004873  0.280837  0.541908 -0.033592    ...     0.013135
# Z_mu_rap  0.874520  0.004487  0.000646 -0.006544    ...    -0.001216
# Z_e_pT   -0.004873  0.280837  0.541908 -0.033592    ...     0.013135
# Z_e_rap   0.553635  0.006149  0.004271  0.008422    ...     0.002650
# m_H      -0.011696  0.284652  0.570407 -0.040047    ...     0.009300
# signal    0.003505 -0.054521 -0.091252  0.002454    ...     0.009233
#
#              e-_pz     e-_pT    e-_rap   Z_mu_pT  Z_mu_rap    Z_e_pT  \
# mu-_m    -0.018894  0.206924 -0.009767  0.281675 -0.006162  0.281675
# mu-_E    -0.015017  0.396864 -0.006733  0.537594 -0.011789  0.537594
# mu+_py    0.009798 -0.031389  0.002501
# mu+_pz    0.394820 -0.019274 -0.002340
# mu+_pT   -0.002630  0.718878 -0.059133
# mu+_rap   0.544821 -0.013485  0.000821
# e+_m      0.001990  0.284862 -0.038711
# e+_E      0.006458  0.576446 -0.083885
# e+_px    -0.005463  0.020385 -0.007031
# e+_py    -0.006638  0.022581 -0.003711
# e+_pz     0.714771  0.024321 -0.000219
# e+_pT     0.002329  0.720969 -0.057986
# e+_rap    0.871981  0.001812 -0.001214
# e-_m     -0.000851  0.278877 -0.061514
# e-_E     -0.004331  0.560248 -0.103393
# e-_px    -0.012025  0.044725 -0.006858
# e-_py     0.002650  0.009300  0.009233
# e-_pz     0.713769 -0.001937 -0.006512
# e-_pT    -0.005720  0.716461 -0.062204
# e-_rap    0.872839 -0.002982  0.000025
# Z_mu_pT  -0.003822  0.894317 -0.028200
# Z_mu_rap  0.624509 -0.012886  0.001093
# Z_e_pT   -0.003822  0.894317 -0.028200
# Z_e_rap   1.000000  0.000205 -0.001055
# m_H       0.000205  1.000000 -0.122168
# signal   -0.001055 -0.122168  1.000000
#
# [34 rows x 34 columns]

# %%
mi=(x - (x == xscar).astype(int)).min().min()

# %%
mi, ma
# Out:
# (-0.5577685980426204, 0.8943174513128607)

# %%
cols = list(all_df.columns)

# %%
n = [None,]*(len(cols[3:31:7]) + len(cols[4:32:7]))

# %%
n = cols[2:30:7]

# %%
n[1::2] = cols[3:31:7]

# %%
n
# Out:
# ['mu-_px', 'mu+_px', 'e+_px', 'e-_px']

# %%
# Compute the correlation matrix
corr = all_df[n].corr()

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# %%
def latex_label(observables):
    latex_observables = []
    for s in observables:
        ss = s.replace('mu', '\mu').replace('pT', 'p_{T}')
        if s.startswith('Z_'):
            ss = '$'+ss.replace('_','^{',1).replace('_','}_{',1)+'}$'
        elif s == 'signal':
            continue
        else:
            ss = ss.replace('-', '^{-}',1).replace('+', '^{+}',1)
            ss = '$'+ss.replace('_','_{',1)+'}$'
        latex_observables.append(ss)
    return latex_observables

# %%
sns.set(style="white")

plot_all_df = all_df
plot_all_df.columns = latex_label(list(plot_all_df.columns)) + ['signal']
plot_corr = plot_all_df.corr()

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0, #vmax=.3,
            square=True, linewidths=.5, cbar_kws={"shrink": .75})

# %%
signal_correlations = pd.DataFrame(corr['signal']).transpose(copy=True)

# %%
observables = list(signal_correlations.columns)[:-1]

# %%
signal_correlations = signal_correlations[observables].transpose(copy=True)

# %%
def latex_observables(df):
    plot_observables = {}
    for s in df.columns:
        ss = s.replace('mu', '\mu').replace('pT', 'p_{T}')
        if s.startswith('Z_'):
            ss = '$'+ss.replace('_','^{',1).replace('_','}_{',1)+'}$'
        else:
            ss = ss.replace('-', '^{-}',1).replace('+', '^{+}',1)
            ss = '$'+ss.replace('_','_{',1)+'}$'
        plot_observables[s] = ss
    return df.rename(columns=plot_observables)

# %%
sns.set(style="white")

plot_signal_correlations = signal_correlations.transpose(copy=True)
plot_signal_correlations = latex_observables(plot_signal_correlations)

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(plot_signal_correlations, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": 0.7, "orientation": "horizontal", 'pad':-0.15})

# %%
abs_signal_correlations = signal_correlations.abs().sort_values('signal', ascending=False)
abs_signal_correlations
# Out:
#             signal
# m_H       0.122168
# mu-_E     0.106910
# e-_E      0.103393
# mu+_E     0.091252
# e+_E      0.083885
# mu-_pT    0.063061
# e-_pT     0.062204
# e-_m      0.061514
# mu+_pT    0.059133
# e+_pT     0.057986
# mu-_m     0.057319
# mu+_m     0.054521
# e+_m      0.038711
# Z_mu_pT   0.028200
# Z_e_pT    0.028200
# mu-_px    0.011322
# e-_py     0.009233
# mu-_py    0.008009
# e+_px     0.007031
# e-_px     0.006858
# e-_pz     0.006512
# e+_py     0.003711
# mu-_rap   0.003505
# mu-_pz    0.003214
# mu+_py    0.002501
# mu+_px    0.002454
# mu+_pz    0.002340
# e+_rap    0.001214
# Z_mu_rap  0.001093
# Z_e_rap   0.001055
# mu+_rap   0.000821
# e+_pz     0.000219
# e-_rap    0.000025

# %%
x1, x2, x3 = corr < -0.15, corr > 0.15, corr == 1.0

# %%
x = (x1 | x2)

# %%
x4 = corr > 100

# %%
x
# Out:
#           mu-_m  mu-_E  mu-_px  mu-_py  mu-_pz  mu-_pT  mu-_rap  mu+_m  mu+_E  \
# mu-_m      True   True   False   False   False    True    False  False   True
# mu-_E      True   True   False   False   False    True    False   True   True
# mu-_px    False  False    True   False   False   False    False  False  False
# mu-_py    False  False   False    True   False   False    False  False  False
# mu-_pz    False  False   False   False    True   False     True  False  False
# mu-_pT     True   True   False   False   False    True    False  False   True
# mu-_rap   False  False   False   False    True   False     True  False  False
# mu+_m     False   True   False   False   False   False    False   True   True
# mu+_E      True   True   False   False   False    True    False   True   True
# mu+_px    False  False   False   False   False   False    False  False  False
# mu+_py    False  False   False   False   False   False    False  False  False
# mu+_pz    False  False   False   False    True   False     True  False  False
# mu+_pT    False   True   False   False   False    True    False   True   True
# mu+_rap   False  False   False   False    True   False     True  False  False
# e+_m      False   True   False   False   False    True    False  False   True
# e+_E       True   True   False   False   False    True    False   True   True
# e+_px     False  False    True   False   False   False    False  False  False
# e+_py     False  False   False    True   False   False    False  False  False
# e+_pz     False  False   False   False    True   False     True  False  False
# e+_pT      True   True   False   False   False    True    False   True   True
# e+_rap    False  False   False   False    True   False     True  False  False
# e-_m      False   True   False   False   False    True    False  False   True
# e-_E       True   True   False   False   False    True    False   True   True
# e-_px     False  False    True   False   False   False    False  False  False
# e-_py     False  False   False    True   False   False    False  False  False
# e-_pz     False  False   False   False    True   False     True  False  False
# e-_pT      True   True   False   False   False    True    False   True   True
# e-_rap    False  False   False   False    True   False     True  False  False
# Z_mu_pT    True   True   False   False   False    True    False   True   True
# Z_mu_rap  False  False   False   False    True   False     True  False  False
# Z_e_pT     True   True   False   False   False    True    False   True   True
# Z_e_rap   False  False   False   False    True   False     True  False  False
# m_H        True   True   False   False   False    True    False   True   True
# signal    False  False   False   False   False   False    False  False  False
#
#           mu+_px   ...    e-_py  e-_pz  e-_pT  e-_rap  Z_mu_pT  Z_mu_rap  \
# mu-_m      False   ...    False  False   True   False     True     False
# mu-_E      False   ...    False  False   True   False     True     False
# mu-_px     False   ...    False  False  False   False    False     False
# mu-_py     False   ...     True  False  False   False    False     False
# mu-_pz     False   ...    False   True  False    True    False      True
# mu-_pT     False   ...    False  False   True   False     True     False
# mu-_rap    False   ...    False   True  False    True    False      True
# mu+_m      False   ...    False  False   True   False     True     False
# mu+_E      False   ...    False  False   True   False     True     False
# mu+_px      True   ...    False  False  False   False    False     False
# mu+_py     False   ...     True  False  False   False    False     False
# mu+_pz     False   ...    False   True  False    True    False      True
# mu+_pT     False   ...    False  False   True   False     True     False
# mu+_rap    False   ...    False   True  False    True    False      True
# e+_m       False   ...    False  False  False   False     True     False
# e+_E       False   ...    False  False   True   False     True     False
# e+_px       True   ...    False  False  False   False    False     False
# e+_py      False   ...    False  False  False   False    False     False
# e+_pz      False   ...    False   True  False    True    False      True
# e+_pT      False   ...    False  False   True   False     True     False
# e+_rap     False   ...    False   True  False    True    False      True
# e-_m       False   ...    False  False   True   False     True     False
# e-_E       False   ...    False  False   True   False     True     False
# e-_px       True   ...    False  False  False   False    False     False
# e-_py      False   ...     True  False  False   False    False     False
# e-_pz      False   ...    False   True  False    True    False      True
# e-_pT      False   ...    False  False   True   False     True     False
# e-_rap     False   ...    False   True  False    True    False      True
# Z_mu_pT    False   ...    False  False   True   False     True     False
# Z_mu_rap   False   ...    False   True  False    True    False      True
# Z_e_pT     False   ...    False  False   True   False     True     False
# Z_e_rap    False   ...    False   True  False    True    False      True
# m_H        False   ...    False  False   True   False     True     False
# signal     False   ...    False  False  False   False    False     False
#
#           Z_e_pT  Z_e_rap    m_H  signal
# mu-_m       True    False   True   False
# mu-_E       True    False   True   False
# mu-_px     False    False  False   False
# mu-_py     False    False  False   False
# mu-_pz     False     True  False   False
# mu-_pT      True    False   True   False
# mu-_rap    False     True  False   False
# mu+_m       True    False   True   False
# mu+_E       True    False   True   False
# mu+_px     False    False  False   False
# mu+_py     False    False  False   False
# mu+_pz     False     True  False   False
# mu+_pT      True    False   True   False
# mu+_rap    False     True  False   False
# e+_m        True    False   True   False
# e+_E        True    False   True   False
# e+_px      False    False  False   False
# e+_py      False    False  False   False
# e+_pz      False     True  False   False
# e+_pT       True    False   True   False
# e+_rap     False     True  False   False
# e-_m        True    False   True   False
# e-_E        True    False   True   False
# e-_px      False    False  False   False
# e-_py      False    False  False   False
# e-_pz      False     True  False   False
# e-_pT       True    False   True   False
# e-_rap     False     True  False   False
# Z_mu_pT     True    False   True   False
# Z_mu_rap   False     True  False   False
# Z_e_pT      True    False   True   False
# Z_e_rap    False     True  False   False
# m_H         True    False   True   False
# signal     False    False  False    True
#
# [34 rows x 34 columns]

# %%
y = x4 == x

# %%
mask = y | x3

# %%
mask.shape == plot_corr.shape
# Out:
# True

# %%
plot_corr.shape
# Out:
# (34, 34)

# %%
mask not
# Out:
#   File "<ipython-input-108-58157210cbcf>", line 1
#     mask not
#             ^
# SyntaxError: invalid syntax
